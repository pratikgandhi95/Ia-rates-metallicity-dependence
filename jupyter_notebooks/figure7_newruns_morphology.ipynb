# %% [markdown]
# #### Plots a comparison of different morphological parameters (stellar mass, r90, v/sigma, axis ratios, etc) for re-simulations with modified SN Ia rates.
#
# @author: Pratik Gandhi pjgandhi@ucdavis.edu
#
# First created: July 2021

# %%
# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy.io import ascii

# %%
# setting matplotlib parameters to make plots look more nicer
plt.rcParams['legend.frameon'] = False
plt.rcParams['savefig.format'] = 'pdf'
plt.rcParams['legend.handletextpad'] = 0.3
plt.rcParams['figure.figsize'] = (5, 17)
plt.rcParams['lines.linewidth'] = 2.5
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.style'] = 'normal'
plt.rcParams['font.variant'] = 'normal'
plt.rcParams['font.weight'] = 'normal'
plt.rcParams['font.stretch'] = 'normal'
plt.rcParams['font.size'] = 23.0
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['axes.linewidth'] = 2.5
plt.rcParams['axes.labelsize'] = 23.0
plt.rcParams['axes.labelpad'] = 6.0
plt.rcParams['axes.titlepad'] = 0.0
plt.rcParams['axes.titlesize'] = 23.0
plt.rcParams['axes.formatter.limits'] = -7,7
plt.rcParams['xtick.major.size'] = 15.0
plt.rcParams['ytick.major.size'] = 15.0
plt.rcParams['xtick.minor.size'] = 8.0
plt.rcParams['ytick.minor.size'] = 8.0
plt.rcParams['xtick.major.pad'] = 12.0
plt.rcParams['ytick.major.pad'] = 12.0
plt.rcParams['xtick.minor.pad'] = 12.0
plt.rcParams['ytick.minor.pad'] = 12.0
plt.rcParams['xtick.major.width'] = 1.6
plt.rcParams['ytick.major.width'] = 1.6
plt.rcParams['xtick.minor.width'] = 0.8
plt.rcParams['ytick.minor.width'] = 0.8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['legend.loc'] = 'best'
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.scatterpoints'] = 1
plt.rcParams['figure.constrained_layout.use'] = False

# %% [markdown]
# #### Handling i/o; reading in data for various sims

# %%
# reading in morphological data files for m11b, m11e, and m12i
data_m12i = ascii.read('./data/newruns-m12i-swb_morphology-check.txt')
data_m11e = ascii.read('./data/newruns-m11e-swb_morphology-check.txt')
data_m11b = ascii.read('./data/newruns-m11b-swb_morphology-check.txt')

# array for x axis labels as per sim names
xlabels = ['M+06 DTD', 'M+17 DTD', '$\\alpha=-0.5$ [$10\\times$]', \
           '$\\alpha=-0.5$ [$100\\times$]', '$\\alpha=-1.0$ [$10\\times$]', \
           '$\\alpha=-1.0$ [$100\\times$]']

# %% [markdown]
# #### Plot: single 4-panel vertical figure comparing stellar mass, R90, v/sigma, and axis ratios for variants of the 3 re-simulations

# %%
# initialising overall figure
fig, ax = plt.subplots(4,1)
fig.set_tight_layout(False)
fig.subplots_adjust(left=0.27, right=0.98, top=0.99, bottom=0.13, wspace=0)

# plotting m12i Mstar values
ax[0].scatter(xlabels, data_m12i['Mgal[Msun]'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11e Mstar values
ax[0].scatter(xlabels, data_m11e['Mgal[Msun]'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11b Mstar values
ax[0].scatter(xlabels, data_m11b['Mgal[Msun]'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label=None)

# plotting m12i r90 values
ax[1].scatter(xlabels, data_m12i['r90[kpc]'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11e r90 values
ax[1].scatter(xlabels, data_m11e['r90[kpc]'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11b r90 values
ax[1].scatter(xlabels, data_m11b['r90[kpc]'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label=None)

# plotting m12i v/sigma values
ax[2].scatter(xlabels, data_m12i['v_sigma'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11e v/sigma values
ax[2].scatter(xlabels, data_m11e['v_sigma'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11b v/sigma values
ax[2].scatter(xlabels, data_m11b['v_sigma'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label=None)

# plotting m12i axis ratio values
ax[3].scatter(xlabels, data_m12i['min_to_maj'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label='m12i ($\\rm{M_*} \sim 10^{10} \\rm{M}_{\\odot}$)')
# plotting m11e axis ratio values
ax[3].scatter(xlabels, data_m11e['min_to_maj'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label='m11e ($\\rm{M_*} \sim 10^{8} \\rm{M}_{\\odot}$)')
# plotting m11b axis ratio values
ax[3].scatter(xlabels, data_m11b['min_to_maj'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label='m11b ($\\rm{M_*} \sim 10^{7} \\rm{M}_{\\odot}$)')

# specifying rest of 1st panel
ax[0].set_ylabel('Stellar Mass [$\\rm{M}_{\\odot}$]')
ax[0].set_yscale('log')
ax[0].set_ylim(10**6.1, 10**11.5)
ax[0].set_yticks(ticks=[10**7, 10**8, 10**9, 10**10, 10**11])
ax[0].tick_params(axis='y', which='minor')

# specifying rest of 2nd panel
ax[1].set_ylabel('Stellar $\\rm{R}_{90}$ [kpc]')
ax[1].set_ylim(5, 19)

# specifying rest of 3rd panel
ax[2].set_ylabel("Stellar v/$\\sigma$")
ax[2].set_ylim(0.1, 1.95)

# specifying rest of 4th panel
ax[3].set_ylabel("Axis ratio (min/maj)")
ax[3].set_ylim(0, 0.9)
ax[3].legend(prop={'size':14}, loc='upper left', ncol=1)

plt.xticks(rotation=45, fontsize=16, ha='right')

# eliminate tick labels on common x axes so only bottom panel has x ticks
plt.setp(ax[0].get_xticklabels(), visible=False)
plt.setp(ax[1].get_xticklabels(), visible=False)
plt.setp(ax[2].get_xticklabels(), visible=False)

# specifying rest of overall figure parameter
fig.subplots_adjust(hspace=0)
plt.savefig('./plots/figure7_newruns-morphology-all.pdf')
plt.show()

# %% [markdown]
# #### additional plots for talk in FIRE seminar

# %%
# initialising figure
plt.rcParams['figure.figsize'] = (6, 5)
fig, ax = plt.subplots(1,1)
fig.set_tight_layout(False)
fig.subplots_adjust(left=0.22, right=0.98, top=0.97, bottom=0.05, wspace=0)

# plotting m12i Mstar values
ax.scatter(xlabels, data_m12i['Mgal[Msun]'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11e Mstar values
ax.scatter(xlabels, data_m11e['Mgal[Msun]'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11b Mstar values
ax.scatter(xlabels, data_m11b['Mgal[Msun]'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label=None)

# specifying rest of 1st panel
ax.set_ylabel('Stellar Mass [$\\rm{M}_{\\odot}$]')
ax.set_yscale('log')
ax.set_ylim(10**6.1, 10**11.3)
ax.set_yticks(ticks=[10**7, 10**8, 10**9, 10**10, 10**11])
ax.tick_params(axis='y', which='minor')
plt.setp(ax.get_xticklabels(), visible=False)
plt.savefig('/Users/pratikgandhi/Desktop/SNrates_fig6a.png', transparent=True)
plt.show()

# %%
# initialising figure
plt.rcParams['figure.figsize'] = (6, 5)
fig, ax = plt.subplots(1,1)
fig.set_tight_layout(False)
fig.subplots_adjust(left=0.22, right=0.98, top=0.97, bottom=0.05, wspace=0)

# plotting m12i r90 values
ax.scatter(xlabels, data_m12i['r90[kpc]'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11e r90 values
ax.scatter(xlabels, data_m11e['r90[kpc]'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11b r90 values
ax.scatter(xlabels, data_m11b['r90[kpc]'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label=None)

# specifying rest of 1st panel
ax.set_ylabel('Stellar $\\rm{R}_{90}$ [kpc]')
ax.set_ylim(5, 19)
plt.setp(ax.get_xticklabels(), visible=False)
plt.savefig('/Users/pratikgandhi/Desktop/SNrates_fig6b.png', transparent=True)
plt.show()

# %%
# initialising figure
plt.rcParams['figure.figsize'] = (6, 6.5)
fig, ax = plt.subplots(1,1)
fig.set_tight_layout(False)
fig.subplots_adjust(left=0.22, right=0.98, top=0.97, bottom=0.27, wspace=0)

# plotting m12i v/sigma values
ax.scatter(xlabels, data_m12i['v_sigma'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11e v/sigma values
ax.scatter(xlabels, data_m11e['v_sigma'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label=None)
# plotting m11b v/sigma values
ax.scatter(xlabels, data_m11b['v_sigma'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label=None)

# specifying rest of 1st panel
ax.set_ylabel("Stellar v/$\\sigma$")
ax.set_ylim(0.1, 1.95)
plt.xticks(rotation=45, fontsize=16, ha='right')
plt.savefig('/Users/pratikgandhi/Desktop/SNrates_fig6c.png', transparent=True)
plt.show()

# %%
# initialising figure
plt.rcParams['figure.figsize'] = (6, 6.5)
fig, ax = plt.subplots(1,1)
fig.set_tight_layout(False)
fig.subplots_adjust(left=0.22, right=0.98, top=0.97, bottom=0.27, wspace=0)

# plotting m12i axis ratio values
ax.scatter(xlabels, data_m12i['min_to_maj'], marker='o', s=180, c='r', \
           edgecolors='k', linewidths=2, \
           label='m12i ($\\rm{M_*} \sim 10^{10} \\rm{M}_{\\odot}$)')
# plotting m11e axis ratio values
ax.scatter(xlabels, data_m11e['min_to_maj'], marker='s', s=160, c='orange', \
           edgecolors='k', linewidths=2, \
           label='m11e ($\\rm{M_*} \sim 10^{8} \\rm{M}_{\\odot}$)')
# plotting m11b axis ratio values
ax.scatter(xlabels, data_m11b['min_to_maj'], marker='X', s=200, c='brown', \
           edgecolors='k', linewidths=2, \
           label='m11b ($\\rm{M_*} \sim 10^{7} \\rm{M}_{\\odot}$)')

# specifying rest of 1st panel
ax.set_ylabel("Axis ratio (min/maj)")
ax.set_ylim(0, 0.9)
plt.xticks(rotation=45, fontsize=16, ha='right')
plt.savefig('/Users/pratikgandhi/Desktop/SNrates_fig6d.png', transparent=True)
plt.show()
